# %% [markdown]
# ### Breakpoints Saved Function

# %%
import pandas as pd
import os

player_name = 'Rudy Quan'
combined_data_shots = pd.read_excel(f'/Users/chloechoe/Desktop/tc/consulting-spring2025/data/mens/{player_name}/combined.xlsx', sheet_name='Shots')
combined_data_points = pd.read_excel(f'/Users/chloechoe/Desktop/tc/consulting-spring2025/data/mens/{player_name}/combined.xlsx', sheet_name='Points')
combined_data_sets = pd.read_excel(f'/Users/chloechoe/Desktop/tc/consulting-spring2025/data/mens/{player_name}/combined.xlsx', sheet_name='Sets')

def breakpoints_saved_function():
    filtered_data = combined_data_points[
        (combined_data_points['Match Server'] == 'host') & 
        (combined_data_points['Break Point'] == True)
    ].copy()

    filtered_data['Breakpoint Saved'] = (filtered_data['Point Winner'] == 'host').astype(int)

    # total breakpoints and saved breakpoints
    total_saved = filtered_data['Breakpoint Saved'].sum()
    total_breakpoints = len(filtered_data)

    percentage_saved = (total_saved / total_breakpoints) * 100 if total_breakpoints > 0 else 0

    return player_name, percentage_saved

# Example usage
print(f'Breakpoints saved by {player_name}:', f'{breakpoints_saved_function()}')
# Out:
# Breakpoints saved by Rudy Quan: ('Rudy Quan', 50.0)

# %% [markdown]
# ### Cj Work

# %%
import pandas as pd
import os

player_name = 'Rudy Quan'
combined_data_shots = pd.read_excel(f'../../data/mens/{player_name}/combined.xlsx', sheet_name='Shots')
combined_data_points = pd.read_excel(f'../../data/mens/{player_name}/combined.xlsx', sheet_name='Points')
combined_data_sets = pd.read_excel(f'../../data/mens/{player_name}/combined.xlsx', sheet_name='Sets')

# %%
combined_data_shots
# Out:
#                   Player  Shot            Type    Stroke     Spin  \
# 0     Carl Emil Overbeck     1           serve     Serve    Slice
# 1     Carl Emil Overbeck     1           serve     Serve    Slice
# 2              Rudy Quan     2          return  Backhand  Topspin
# 3     Carl Emil Overbeck     3  serve_plus_one  Forehand  Topspin
# 4     Carl Emil Overbeck     1           serve     Serve     Kick
# ...                  ...   ...             ...       ...      ...
# 9246  Cesar Bouchelaghem    29            none  Forehand     Flat
# 9247           Rudy Quan    30            none  Forehand  Topspin
# 9248  Cesar Bouchelaghem    31            none  Backhand  Topspin
# 9249           Rudy Quan    32            none  Forehand     Flat
# 9250  Cesar Bouchelaghem    33            none  Forehand    Slice
#
#       Speed (MPH)  Point  Game  Set Bounce Depth  ... Hit Side   Hit (x)  \
# 0       43.357174      1     0    0        short  ...     near -1.060547
# 1       86.126060      2     0    0        short  ...     near -0.882324
# 2       48.867477      2     0    0         deep  ...      far  3.687500
# 3       73.100418      2     0    0          out  ...     near -0.642090
# 4       30.364021      3     0    0        short  ...     near  0.648438
# ...           ...    ...   ...  ...          ...  ...      ...       ...
# 9246    62.750256    118    18    2         deep  ...      far -3.736328
# 9247    63.335819    118    18    2         deep  ...     near  3.062500
# 9248    32.885406    118    18    2        short  ...      far -0.460693
# 9249    43.428860    118    18    2         deep  ...     near  2.134766
# 9250    32.520355    118    18    2        short  ...      far -0.620605
#
#         Hit (y)   Hit (z)      Direction Result Favorited  Start Time  \
# 0      0.076316  2.337891       out wide    Net     False    05:45:18
# 1      0.896628  2.166016       out wide     In     False    05:45:37
# 2     24.927538  1.308594  down the line     In     False    05:45:38
# 3     -1.564309  1.422852     inside out    Out     False    05:45:40
# 4      0.113293  2.228516       out wide    Out     False    05:45:59
# ...         ...       ...            ...    ...       ...         ...
# 9246  25.427538  1.285156    cross court     In     False    01:44:01
# 9247  -1.212747  0.886230  down the line     In     False    01:44:02
# 9248  23.755663  1.542969      inside in    Net     False    01:44:03
# 9249   0.857566  1.347656    cross court     In     False    01:44:07
# 9250  22.240038  2.148438    cross court     In     False    01:44:09
#
#        Video Time                   __source_file__
# 0        7.330000         RudyQuan_Cal_1_25_25.xlsx
# 1       26.590000         RudyQuan_Cal_1_25_25.xlsx
# 2       27.480000         RudyQuan_Cal_1_25_25.xlsx
# 3       29.090000         RudyQuan_Cal_1_25_25.xlsx
# 4       48.389999         RudyQuan_Cal_1_25_25.xlsx
# ...           ...                               ...
# 9246  8544.179688  RudyQuan_Washington_3_30_35.xlsx
# 9247  8545.379883  RudyQuan_Washington_3_30_35.xlsx
# 9248  8546.780273  RudyQuan_Washington_3_30_35.xlsx
# 9249  8550.980469  RudyQuan_Washington_3_30_35.xlsx
# 9250  8552.480469  RudyQuan_Washington_3_30_35.xlsx
#
# [9251 rows x 26 columns]

# %%
filtered_data = combined_data_points[(combined_data_points['Match Server'] == 'host') & 
                                     (combined_data_points['Break Point'] == True)
                                     ].copy()

filtered_data['Breakpoint Saved'] = (filtered_data['Point Winner'] == 'host').astype(int)
filtered_data['Breakpoint Saved'].mean()

filtered_data['Point Winner'].value_counts(normalize=True).get('host', 0)
# Out:
# 0.5

# %%
def breakpoints_saved_function(data):

    # Filter Data
    filtered_data = data[(data['Match Server'] == 'host') & 
                         (data['Break Point'] == True)
                         ].copy()

    percentage = (filtered_data['Point Winner'].value_counts(normalize=True).get('host', 0) * 100).round(2)

    return percentage

# %%
breakpoints_saved_percentage = breakpoints_saved_function(combined_data_points)
breakpoints_saved_percentage
# Out:
# 50.0
