# %% [markdown]
# ## Notebook Start

# %% [markdown]
# ### Load Packages

# %%
import requests
import pandas as pd

# %%
api_url = "https://uclabruins.com/api/v2/EventsResults/results?sportId=9&$pageIndex=0&$pageSize=50"
response = requests.get(api_url)

# %%
data = response.json()
data["items"][0]
# Out:
# {'id': 34034,
#  'gamePregameStoryId': 69064,
#  'gamePostgameStoryId': 69072,
#  'date': '2025-05-16T17:00:00',
#  'endDate': None,
#  'dateUtc': '2025-05-17T00:00:00.0000001Z',
#  'endDateUtc': None,
#  'time': '5:00 PM',
#  'isDoubleHeader': False,
#  'showAtVs': True,
#  'tbd': False,
#  'allDay': False,
#  'teamPrefix': None,
#  'status': 'O',
#  'locationIndicator': 'N',
#  'neutralHometeam': False,
#  'location': 'Waco, Texas',
#  'isConference': False,
#  'conference': 'Big Ten',
#  'conferenceAbbrev': 'Big Ten',
#  'conferenceLogo': None,
#  'isSpotlight': False,
#  'type': 'recent',
#  'tournament': "NCAA Men's Tennis Championship",
#  'ticketLink': None,
#  'sport': {'nonSport': False,
#   'atVs': True,
#   'gameSynonym': 'Match',
#   'globalSportShortName': 'mten',
#   'shortTitle': '',
#   'scheduleId': 2675,
#   'abbrev': 'MTEN',
#   'shortDisplay': None,
#   'shortName': 'mten',
#   'globalSportId': None,
#   'globalSportNameSlug': None,
#   'globalSportGender': 'm',
#   'id': 9,
#   'title': "Men's Tennis"},
#  'schedule': {'id': 2675,
#   'title': "2024-25 Men's Tennis Schedule",
#   'url': '/sports/mens-tennis/schedule'},
#  'opponent': {'id': 42,
#   'title': 'No. 3 seed Texas',
#   'image': 'https://d3kmx57qvxfvw9.cloudfront.net/images/logos/texas_200x200.png',
#   'prefix': 'No. 3 seed',
#   'name': 'Texas'},
#  'media': {'video': 'https://www.espn.com/espnplus/player/_/id/bb230f53-5856-42dd-b00f-800543382183',
#   'videoText': None,
#   'audio': None,
#   'audioText': None,
#   'stats': 'https://ioncourt.com/ties/6822bf92b4050de812353315',
#   'tickets': None,
#   'gameNote': None,
#   'gamePromotionName': None,
#   'tv': 'ESPN+',
#   'tvImage': None,
#   'tvImageLink': None,
#   'radio': None,
#   'custom1': None,
#   'custom2': None,
#   'custom3': None,
#   'gameFiles': [{'cssClass': None,
#     'title': 'Results (PDF)',
#     'url': '/documents/2025/5/17/Results_20250516_MTEN.pdf'}],
#   'program': None,
#   'programText': None},
#  'story': {'id': 69072,
#   'title': "Men's Tennis Has Postseason Run Stopped in NCAA Quarterfinals",
#   'url': '/news/2025/5/16/mens-tennis-has-postseason-run-stopped-in-ncaa-quarterfinals',
#   'relativeImageSource': '/images/2025/5/16/DSC_9055.jpg',
#   'absoluteImageSource': 'https://uclabruins.com/images/2025/5/16/DSC_9055.jpg',
#   'date': '2025-05-17T06:43:08.697'},
#  'result': {'status': 'L',
#   'teamScore': '1',
#   'opponentScore': '4',
#   'preScore': None,
#   'postScore': None,
#   'boxScore': '/boxscore.aspx?id=34034',
#   'gameId': 34034,
#   'lineScores': {'game_winner': 'H',
#    'this_team_is_home_team': False,
#    'home_full_name': 'Texas',
#    'home_short_name': 'TEX',
#    'away_full_name': 'UCLA',
#    'away_short_name': 'UCLA',
#    'period_label': None,
#    'periods': ['F'],
#    'period_home_score': ['4'],
#    'period_away_score': ['1']}},
#  'gameFacility': {'id': 339, 'title': 'Hurd Tennis Center', 'url': None},
#  'promotion': {'name': None,
#   'link': None,
#   'image': None,
#   'caption': None,
#   'altText': None},
#  'eventImage': {'image': None, 'altText': None, 'caption': None, 'link': None},
#  'gameDate': '2025-05-16T17:00:00',
#  'gameId': 34034}

# %%
data["items"][0].get("result")
# Out:
# {'status': 'L',
#  'teamScore': '1',
#  'opponentScore': '4',
#  'preScore': None,
#  'postScore': None,
#  'boxScore': '/boxscore.aspx?id=34034',
#  'gameId': 34034,
#  'lineScores': {'game_winner': 'H',
#   'this_team_is_home_team': False,
#   'home_full_name': 'Texas',
#   'home_short_name': 'TEX',
#   'away_full_name': 'UCLA',
#   'away_short_name': 'UCLA',
#   'period_label': None,
#   'periods': ['F'],
#   'period_home_score': ['4'],
#   'period_away_score': ['1']}}

# %%
bsurllist = []
box_score_api_urls = []

if response.status_code == 200:
    data = response.json()
    all_games = []

    for game in data.get("items", []):
        game_data = {}
        game_data["date"] = game.get("date", "No date available").split("T")[0]
        game_data["location"] = game.get("location", "No location available")
        
        opponent_title = game.get("opponent", {}).get("title", "")
        opponent_parts = opponent_title.split()

        # Only assign seed if it exists
        seed = opponent_parts[1] if len(opponent_parts) > 1 else None
        game_data["opponent_seed"] = seed if seed and seed.isdigit() else None

        game_data["isConference"] = game.get("isConference")
        game_data["tournament"] = game.get("tournament")
        
        result = game.get("result", {}) or {}
        boxScore = result.get("boxScore")
        if isinstance(boxScore, str) and boxScore.startswith("/"):
            boxScore = "https://uclabruins.com/api/v2/Stats/boxscore/" + boxScore.split("=")[-1]
        game_data["boxScore"] = boxScore

        game_data["overallScore"] = str(result.get("teamScore")) + '-' + str(result.get("opponentScore"))

        lineScores = result.get("lineScores", {}) or {}

        winner_code = lineScores.get("game_winner")
        winner_label = {'H': 'home', 'A': 'away'}.get(winner_code, None)

        game_data["game_winner_label"] = winner_label   

        game_data["this_team_is_home_team"] = lineScores.get("this_team_is_home_team")
        game_data["home_full_name"] = lineScores.get("home_full_name")
        game_data["away_full_name"] = lineScores.get("away_full_name")
        
        facility = game.get("gameFacility", {}) or {}
        game_data["facility_id"] = facility.get("id")
        game_data["facility_location"] = facility.get("title")

        all_games.append(game_data)

    df = pd.DataFrame(all_games)
else:
    print(f"Error: Unable to fetch data (Status Code: {response.status_code})")

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df.head(25)
# Out:
#           date             location opponent_seed  isConference  \
# 0   2025-05-16          Waco, Texas             3         False
# 1   2025-05-09  Los Angeles, Calif.          None         False
# 2   2025-05-03     Berkeley, Calif.            11         False
# 3   2025-05-02     Berkeley, Calif.          None         False
# 4   2025-04-27       Columbus, Ohio             1         False
# 5   2025-04-26       Columbus, Ohio             3         False
# 6   2025-04-25       Columbus, Ohio             7         False
# 7   2025-04-20        Lincoln, Neb.            41          True
# 8   2025-04-18        Madison, Wis.            58          True
# 9   2025-04-13  Los Angeles, Calif.            28          True
# 10  2025-04-11  Los Angeles, Calif.            21          True
# 11  2025-04-06   State College, Pa.          None          True
# 12  2025-04-04       Columbus, Ohio             3          True
# 13  2025-04-01  Los Angeles, Calif.            30          True
# 14  2025-03-30  Los Angeles, Calif.            47          True
# 15  2025-03-29  Los Angeles, Calif.            58          True
# 16  2025-03-23       Evanston, Ill.            60          True
# 17  2025-03-21         Urbana, Ill.            23          True
# 18  2025-03-09  Los Angeles, Calif.            44          True
# 19  2025-03-07  Los Angeles, Calif.            38          True
# 20  2025-02-28     La Jolla, Calif.          None         False
# 21  2025-02-22  Los Angeles, Calif.            25         False
# 22  2025-02-16  Los Angeles, Calif.            25         False
# 23  2025-02-02  Los Angeles, Calif.            13         False
# 24  2025-02-01  Los Angeles, Calif.          None         False
#
#                             tournament  \
# 0       NCAA Men's Tennis Championship
# 1            NCAA Super-Regional Round
# 2         NCAA First and Second Rounds
# 3         NCAA First and Second Rounds
# 4      Big Ten Men's Tennis Tournament
# 5      Big Ten Men's Tennis Tournament
# 6      Big Ten Men's Tennis Tournament
# 7                                 None
# 8                                 None
# 9                                 None
# 10                                None
# 11                                None
# 12                                None
# 13                                None
# 14                                None
# 15                                None
# 16                                None
# 17                                None
# 18                                None
# 19                                None
# 20  Pacific Coast Doubles Championship
# 21                                None
# 22                                None
# 23                                None
# 24                                None
#
#                                              boxScore overallScore  \
# 0   https://uclabruins.com/api/v2/Stats/boxscore/3...          1-4
# 1   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-2
# 2   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-2
# 3   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-0
# 4   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-3
# 5   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-0
# 6   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-1
# 7   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-1
# 8   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-0
# 9   https://uclabruins.com/api/v2/Stats/boxscore/3...          4-1
# 10  https://uclabruins.com/api/v2/Stats/boxscore/3...          5-0
# 11  https://uclabruins.com/api/v2/Stats/boxscore/3...          4-0
# 12  https://uclabruins.com/api/v2/Stats/boxscore/3...          0-4
# 13  https://uclabruins.com/api/v2/Stats/boxscore/3...          3-4
# 14  https://uclabruins.com/api/v2/Stats/boxscore/3...          4-0
# 15  https://uclabruins.com/api/v2/Stats/boxscore/3...          4-0
# 16  https://uclabruins.com/api/v2/Stats/boxscore/3...          4-0
# 17  https://uclabruins.com/api/v2/Stats/boxscore/3...          4-1
# 18  https://uclabruins.com/api/v2/Stats/boxscore/3...          7-0
# 19  https://uclabruins.com/api/v2/Stats/boxscore/3...          7-0
# 20                                               None    None-None
# 21  https://uclabruins.com/api/v2/Stats/boxscore/3...          3-4
# 22  https://uclabruins.com/api/v2/Stats/boxscore/3...          2-4
# 23  https://uclabruins.com/api/v2/Stats/boxscore/3...          0-4
# 24  https://uclabruins.com/api/v2/Stats/boxscore/3...          2-4
#
#    game_winner_label this_team_is_home_team home_full_name    away_full_name  \
# 0               home                  False          Texas              UCLA
# 1               home                  False           UCLA               USC
# 2               away                  False     California              UCLA
# 3               home                  False           UCLA  UC Santa Barbara
# 4               away                  False     Ohio State              UCLA
# 5               home                  False           UCLA    Michigan State
# 6               home                  False           UCLA          Michigan
# 7               away                  False       Nebraska              UCLA
# 8               away                  False      Wisconsin              UCLA
# 9               home                  False           UCLA    Michigan State
# 10              home                  False           UCLA          Michigan
# 11              away                  False     Penn State              UCLA
# 12              home                  False     Ohio State              UCLA
# 13              home                  False            USC              UCLA
# 14              home                  False           UCLA        Washington
# 15              home                  False           UCLA            Oregon
# 16              away                  False   Northwestern              UCLA
# 17              away                  False       Illinois              UCLA
# 18              home                  False           UCLA            Purdue
# 19              home                  False           UCLA           Indiana
# 20              None                   None           None              None
# 21              away                  False           UCLA               USC
# 22              away                  False           UCLA        Pepperdine
# 23              away                  False           UCLA          Stanford
# 24              away                  False           UCLA        California
#
#     facility_id                   facility_location
# 0         339.0                  Hurd Tennis Center
# 1          10.0           Los Angeles Tennis Center
# 2         213.0              Hellman Tennis Complex
# 3         213.0              Hellman Tennis Complex
# 4         359.0                 Auer Tennis Complex
# 5         359.0                 Auer Tennis Complex
# 6         211.0             Ty Tucker Tennis Center
# 7         329.0  Sid and Hazel Dillon Tennis Center
# 8         328.0              Nielsen Tennis Stadium
# 9          10.0           Los Angeles Tennis Center
# 10         10.0           Los Angeles Tennis Center
# 11        327.0                 Sarni Tennis Center
# 12        211.0             Ty Tucker Tennis Center
# 13        193.0      David X. Marks Tennis Stadium
# 14         10.0           Los Angeles Tennis Center
# 15         10.0           Los Angeles Tennis Center
# 16        326.0                 Combe Tennis Center
# 17        338.0                Atkins Tennis Center
# 18         10.0           Los Angeles Tennis Center
# 19         10.0           Los Angeles Tennis Center
# 20        199.0         La Jolla Beach Tennis Club
# 21         10.0           Los Angeles Tennis Center
# 22         10.0           Los Angeles Tennis Center
# 23         10.0           Los Angeles Tennis Center
# 24         10.0           Los Angeles Tennis Center

# %% [markdown]
# ### Parse Individual Match Links

# %%
url = df.loc[0, 'boxScore']
url
# Out:
# 'https://uclabruins.com/api/v2/Stats/boxscore/34034'

# %%
response = requests.get(url, timeout=10) 
response.raise_for_status() 
data = response.json()
data
# Out:
# {'pdfDoc': 'https://dxbhsrqyrr690.cloudfront.net/sidearm.nextgen.sites/uclabruins.com/stats/mten/2024/pdf/20250517121633-250516M.pdf',
#  'thisTeamIsHomeTeam': False,
#  'venue': {'date': '5/16/2025',
#   'oldDate': '0',
#   'time': '7:00 PM',
#   'start': '7:00 PM',
#   'end': '0',
#   'duration': '',
#   'location': 'Waco, TX',
#   'arena': 'Hurd Tennis Center',
#   'stadium': None,
#   'isALeagueGame': False,
#   'isNeutral': True,
#   'isAPostseasonGame': True,
#   'attendance': '0',
#   'officials': [],
#   'rules': {'doublesone': '1',
#    'doublestwo': '0',
#    'indivonly': '0',
#    'suspended': '0',
#    'format': '1',
#    'squash': '0'},
#   'notes': ['NCAA Championship - Quarterfinal Round'],
#   'tournament': False,
#   'tournamentName': ''},
#  'homeTeam': {'id': 'TEX',
#   'code': '',
#   'name': 'Texas',
#   'logo': '/images/logos/texas_200x200.png',
#   'record': '((29-4))',
#   'isTenantTeam': False,
#   'players': [{'name': 'Pierre-Yves Bailly',
#     'oldName': 'Pierre-Yves Bailly',
#     'playerFirstLastName': None,
#     'checkName': 'BAILLY,PIERRE-YVES',
#     'nameFromStats': 'Pierre-Yves Bailly',
#     'uniform': '1',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '3',
#      'tied': '0',
#      'won': '1'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '3',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Jonah Braswell',
#     'oldName': 'Jonah Braswell',
#     'playerFirstLastName': None,
#     'checkName': 'BRASWELL,JONAH',
#     'nameFromStats': 'Jonah Braswell',
#     'uniform': '2',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '116',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '5',
#      'tied': '1',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '2',
#      'tied': '0',
#      'won': '1'}},
#    {'name': 'Lucas Brown',
#     'oldName': 'Lucas Brown',
#     'playerFirstLastName': None,
#     'checkName': 'BROWN,LUCAS',
#     'nameFromStats': 'Lucas Brown',
#     'uniform': '3',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '6',
#      'tied': '1',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '1',
#      'tied': '0',
#      'won': '1'}},
#    {'name': 'Evan Burnett',
#     'oldName': 'Evan Burnett',
#     'playerFirstLastName': None,
#     'checkName': 'BURNETT,EVAN',
#     'nameFromStats': 'Evan Burnett',
#     'uniform': '4',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '0',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Sebastian Eriksson',
#     'oldName': 'Sebastian Eriksson',
#     'playerFirstLastName': None,
#     'checkName': 'ERIKSSON,SEBASTIAN',
#     'nameFromStats': 'Sebastian Eriksson',
#     'uniform': '5',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '35',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '4',
#      'tied': '0',
#      'won': '1'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '3',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Sebastian Gorzny',
#     'oldName': 'Sebastian Gorzny',
#     'playerFirstLastName': None,
#     'checkName': 'GORZNY,SEBASTIAN',
#     'nameFromStats': 'Sebastian Gorzny',
#     'uniform': '6',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '110',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '2',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '2',
#      'tied': '0',
#      'won': '1'}},
#    {'name': 'Timo Legout',
#     'oldName': 'Timo Legout',
#     'playerFirstLastName': None,
#     'checkName': 'LEGOUT,TIMO',
#     'nameFromStats': 'Timo Legout',
#     'uniform': '7',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '20',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '1',
#      'tied': '0',
#      'won': '1'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '1',
#      'tied': '0',
#      'won': '1'}},
#    {'name': 'Oliver Ojakaar',
#     'oldName': 'Oliver Ojakaar',
#     'playerFirstLastName': None,
#     'checkName': 'OJAKAAR,OLIVER',
#     'nameFromStats': 'Oliver Ojakaar',
#     'uniform': '8',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '0',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Rahul Sachdev',
#     'oldName': 'Rahul Sachdev',
#     'playerFirstLastName': None,
#     'checkName': 'SACHDEV,RAHUL',
#     'nameFromStats': 'Rahul Sachdev',
#     'uniform': '9',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '0',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'No player',
#     'oldName': 'No player',
#     'playerFirstLastName': None,
#     'checkName': 'PLAYER,NO',
#     'nameFromStats': 'No player',
#     'uniform': 'TM',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '0',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}}],
#   'totals': {'singlesWon': '3',
#    'singlesLost': '1',
#    'doublesWon': '1',
#    'doublesLost': '1'},
#   'singles': [{'position': '1',
#     'tournamentTeam': '',
#     'opponent': 'Rudy Quan',
#     'opponentRank': ' (20/-)',
#     'outcome': 'W',
#     'score': 'Won 7-5, 6-2',
#     'player1': 'Timo Legout',
#     'player2': '',
#     'ranking': '1/-'},
#    {'position': '2',
#     'tournamentTeam': '',
#     'opponent': 'Emon van Loben Sels',
#     'opponentRank': ' (110/-)',
#     'outcome': 'L',
#     'score': 'Loss 3-6, 6-7 (2-7)',
#     'player1': 'Sebastian Gorzny',
#     'player2': '',
#     'ranking': '26/-'},
#    {'position': '3',
#     'tournamentTeam': '',
#     'opponent': 'Kaylan Bigun',
#     'opponentRank': '',
#     'outcome': 'W',
#     'score': 'Won 6-4, 6-4',
#     'player1': 'Pierre-Yves Bailly',
#     'player2': '',
#     'ranking': '54/-'},
#    {'position': '4',
#     'tournamentTeam': '',
#     'opponent': 'Spencer Johnson',
#     'opponentRank': ' (35/-)',
#     'outcome': 'W',
#     'score': 'Won 6-4, 6-4',
#     'player1': 'Sebastian Eriksson',
#     'player2': '',
#     'ranking': '-/-'},
#    {'position': '5',
#     'tournamentTeam': '',
#     'opponent': 'Aadarsh Tripathi',
#     'opponentRank': ' (116/-)',
#     'outcome': 'u',
#     'score': ' 7-6 (9-7), 2-1, unfinished',
#     'player1': 'Jonah Braswell',
#     'player2': '',
#     'ranking': '72/-'},
#    {'position': '6',
#     'tournamentTeam': '',
#     'opponent': 'Giacomo Revelli',
#     'opponentRank': '',
#     'outcome': 'u',
#     'score': ' 6-2, 5-7, unfinished',
#     'player1': 'Lucas Brown',
#     'player2': '',
#     'ranking': '-/-'}],
#   'doubles': [{'position': '1',
#     'tournamentTeam': '',
#     'opponent': 'A. Hoogmartens / Giacomo Revelli',
#     'opponentRank': '',
#     'outcome': 'W',
#     'score': 'Won 7-6 (7-3)',
#     'player1': 'Lucas Brown',
#     'player2': 'Timo Legout',
#     'ranking': '10/-'},
#    {'position': '2',
#     'tournamentTeam': '',
#     'opponent': 'Spencer Johnson / Aadarsh Tripathi',
#     'opponentRank': '',
#     'outcome': 'W',
#     'score': 'Won 6-4',
#     'player1': 'Jonah Braswell',
#     'player2': 'Sebastian Gorzny',
#     'ranking': '66/-'},
#    {'position': '3',
#     'tournamentTeam': '',
#     'opponent': 'Gianluca Ballotta / Emon van Loben Sels',
#     'opponentRank': '',
#     'outcome': 'L',
#     'score': 'Loss 5-7',
#     'player1': 'Pierre-Yves Bailly',
#     'player2': 'Sebastian Eriksson',
#     'ranking': '81/-'}],
#   'doublesTeams': [{'name': 'Lucas Brown|Timo Legout',
#     'oldName': None,
#     'playerFirstLastName': None,
#     'checkName': None,
#     'nameFromStats': None,
#     'uniform': '3|7',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': None,
#     'singles': None,
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '1',
#      'tied': '0',
#      'won': '1'}},
#    {'name': 'Jonah Braswell|Sebastian Gorzny',
#     'oldName': None,
#     'playerFirstLastName': None,
#     'checkName': None,
#     'nameFromStats': None,
#     'uniform': '2|6',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': None,
#     'singles': None,
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '2',
#      'tied': '0',
#      'won': '1'}},
#    {'name': 'Pierre-Yves Bailly|Sebastian Eriksson',
#     'oldName': None,
#     'playerFirstLastName': None,
#     'checkName': None,
#     'nameFromStats': None,
#     'uniform': '1|5',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': None,
#     'singles': None,
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '3',
#      'tied': '0',
#      'won': '0'}}],
#   'oldDate': None,
#   'gameTime': None,
#   'tournament': False,
#   'tournamentName': None,
#   'location': None,
#   'overallRecord': '29-4',
#   'confRecord': '0-0',
#   'thisTeamWon': False,
#   'score': None,
#   'rank': None,
#   'ranknat': '3',
#   'rankreg': '0',
#   'gameDate': None,
#   'gameOpponent': None,
#   'boxscoreUrl': None,
#   'gameOpponentAbbreviation': None,
#   'gameOpponentScore': None,
#   'isAtHome': False,
#   'atNeutral': False,
#   'atConferenceGame': False,
#   'gameId': None,
#   'gameScore': None,
#   'winOrLoss': None},
#  'visitingTeam': {'id': 'UCLA',
#   'code': '',
#   'name': 'UCLA',
#   'logo': '/images/logos/site/site.png',
#   'record': '((19-9))',
#   'isTenantTeam': True,
#   'players': [{'name': 'Ballotta, Gianluca',
#     'oldName': 'Gianluca Ballotta',
#     'playerFirstLastName': 'Gianluca Ballotta',
#     'checkName': 'BALLOTTA,GIANLUCA',
#     'nameFromStats': 'Gianluca Ballotta',
#     'uniform': '1',
#     'rosterPlayerId': '14680',
#     'playerImageUrl': '/images/2025/1/16/Ballotta_Gianluca_006C_TktQ6.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/gianluca-ballotta/14680',
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '81',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '3',
#      'tied': '0',
#      'won': '1'}},
#    {'name': 'Hoogmartens, Alexander',
#     'oldName': 'A. Hoogmartens',
#     'playerFirstLastName': 'Alexander Hoogmartens',
#     'checkName': 'HOOGMARTENS,A',
#     'nameFromStats': 'A. Hoogmartens',
#     'uniform': '2',
#     'rosterPlayerId': '14681',
#     'playerImageUrl': '/images/2025/1/16/Hoogmartens_Alexander_004C_2CklZ.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/alexander-hoogmartens/14681',
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '10',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '1',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Johnson, Spencer',
#     'oldName': 'Spencer Johnson',
#     'playerFirstLastName': 'Spencer Johnson',
#     'checkName': 'JOHNSON,SPENCER',
#     'nameFromStats': 'Spencer Johnson',
#     'uniform': '3',
#     'rosterPlayerId': '14682',
#     'playerImageUrl': '/images/2025/1/16/Johnson_Spencer_005C_0QJ89.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/spencer-johnson/14682',
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '4',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '66',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '2',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Quan, Rudy',
#     'oldName': 'Rudy Quan',
#     'playerFirstLastName': 'Rudy Quan',
#     'checkName': 'QUAN,RUDY',
#     'nameFromStats': 'Rudy Quan',
#     'uniform': '4',
#     'rosterPlayerId': '14692',
#     'playerImageUrl': '/images/2025/1/16/Quan_Rudy_002C_BpC45.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/rudy-quan/14692',
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '1',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '1',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Revelli, Giacomo',
#     'oldName': 'Giacomo Revelli',
#     'playerFirstLastName': 'Giacomo Revelli',
#     'checkName': 'REVELLI,GIACOMO',
#     'nameFromStats': 'Giacomo Revelli',
#     'uniform': '5',
#     'rosterPlayerId': '14683',
#     'playerImageUrl': '/images/2025/1/16/Revetli_Giacomo_002C_OGrOM.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/giacomo-revelli/14683',
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '6',
#      'tied': '1',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '10',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '1',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Tripathi, Aadarsh',
#     'oldName': 'Aadarsh Tripathi',
#     'playerFirstLastName': 'Aadarsh Tripathi',
#     'checkName': 'TRIPATHI,AADARSH',
#     'nameFromStats': 'Aadarsh Tripathi',
#     'uniform': '6',
#     'rosterPlayerId': '14684',
#     'playerImageUrl': '/images/2025/1/16/Tripathi_Aadarsh_006C_JTF5O.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/aadarsh-tripathi/14684',
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '72',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '5',
#      'tied': '1',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '66',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '2',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'van Loben Sels, Emon',
#     'oldName': 'Emon van Loben Sels',
#     'playerFirstLastName': 'Emon van Loben Sels',
#     'checkName': 'SELS,EMON VAN LOBEN',
#     'nameFromStats': 'Emon van Loben Sels',
#     'uniform': '7',
#     'rosterPlayerId': '14685',
#     'playerImageUrl': '/images/2025/1/16/van_Loben_Sels_Emon_003C_cRlhf.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/emon-van-loben-sels/14685',
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '26',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '2',
#      'tied': '0',
#      'won': '1'},
#     'doubles': {'tournament': False,
#      'ranknat': '81',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '3',
#      'tied': '0',
#      'won': '1'}},
#    {'name': 'von Bismarck, Leo',
#     'oldName': 'Leo von Bismarck',
#     'playerFirstLastName': 'Leo von Bismarck',
#     'checkName': 'BISMARCK,LEO VON',
#     'nameFromStats': 'Leo von Bismarck',
#     'uniform': '8',
#     'rosterPlayerId': '14693',
#     'playerImageUrl': '/images/2025/1/16/von_Bismarck_Leo_004C_ZRmGF.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/leo-von-bismarck/14693',
#     'gamePlayed': '0',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Bigun, Kaylan',
#     'oldName': 'Kaylan Bigun',
#     'playerFirstLastName': 'Kaylan Bigun',
#     'checkName': 'BIGUN,KAYLAN',
#     'nameFromStats': 'Kaylan Bigun',
#     'uniform': '9',
#     'rosterPlayerId': '15117',
#     'playerImageUrl': '/images/2025/1/16/Bigun_Kaylan_008C_BfRYI.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/kaylan-bigun/15117',
#     'gamePlayed': '1',
#     'singles': {'tournament': False,
#      'ranknat': '54',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '3',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Chinlund, Cassius',
#     'oldName': 'Cassius Chinlund',
#     'playerFirstLastName': 'Cassius Chinlund',
#     'checkName': 'CHINLUND,CASSIUS',
#     'nameFromStats': 'Cassius Chinlund',
#     'uniform': '10',
#     'rosterPlayerId': '15118',
#     'playerImageUrl': '/images/2025/1/16/Chinlund_Cassius_005C_ckCJt.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/cassius-chinlund/15118',
#     'gamePlayed': '0',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Crabel, Andrei',
#     'oldName': 'Andrei Crabel',
#     'playerFirstLastName': 'Andrei Crabel',
#     'checkName': 'CRABEL,ANDREI',
#     'nameFromStats': 'Andrei Crabel',
#     'uniform': '11',
#     'rosterPlayerId': '15119',
#     'playerImageUrl': '/images/2025/1/16/Crabel_Andrei_002C_4AAGu.jpg',
#     'playerUrl': '/sports/mens-tennis/roster/andrei-crabel/15119',
#     'gamePlayed': '0',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'No player',
#     'oldName': 'No player',
#     'playerFirstLastName': None,
#     'checkName': 'PLAYER,NO',
#     'nameFromStats': 'No player',
#     'uniform': 'TM',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': '0',
#     'singles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'},
#     'doubles': {'tournament': False,
#      'ranknat': '0',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '0',
#      'tied': '0',
#      'won': '0'}}],
#   'totals': {'singlesWon': '1',
#    'singlesLost': '3',
#    'doublesWon': '0',
#    'doublesLost': '2'},
#   'singles': [{'position': '1',
#     'tournamentTeam': '',
#     'opponent': 'Timo Legout',
#     'opponentRank': ' (1/-)',
#     'outcome': 'L',
#     'score': 'Loss 5-7, 2-6',
#     'player1': 'Rudy Quan',
#     'player2': '',
#     'ranking': '20/-'},
#    {'position': '2',
#     'tournamentTeam': '',
#     'opponent': 'Sebastian Gorzny',
#     'opponentRank': ' (26/-)',
#     'outcome': 'W',
#     'score': 'Won 6-3, 7-6 (7-2)',
#     'player1': 'Emon van Loben Sels',
#     'player2': '',
#     'ranking': '110/-'},
#    {'position': '3',
#     'tournamentTeam': '',
#     'opponent': 'Pierre-Yves Bailly',
#     'opponentRank': ' (54/-)',
#     'outcome': 'L',
#     'score': 'Loss 4-6, 4-6',
#     'player1': 'Kaylan Bigun',
#     'player2': '',
#     'ranking': '-/-'},
#    {'position': '4',
#     'tournamentTeam': '',
#     'opponent': 'Sebastian Eriksson',
#     'opponentRank': '',
#     'outcome': 'L',
#     'score': 'Loss 4-6, 4-6',
#     'player1': 'Spencer Johnson',
#     'player2': '',
#     'ranking': '35/-'},
#    {'position': '5',
#     'tournamentTeam': '',
#     'opponent': 'Jonah Braswell',
#     'opponentRank': ' (72/-)',
#     'outcome': 'u',
#     'score': ' 6-7 (7-9), 1-2, unfinished',
#     'player1': 'Aadarsh Tripathi',
#     'player2': '',
#     'ranking': '116/-'},
#    {'position': '6',
#     'tournamentTeam': '',
#     'opponent': 'Lucas Brown',
#     'opponentRank': '',
#     'outcome': 'u',
#     'score': ' 2-6, 7-5, unfinished',
#     'player1': 'Giacomo Revelli',
#     'player2': '',
#     'ranking': '-/-'}],
#   'doubles': [{'position': '1',
#     'tournamentTeam': '',
#     'opponent': 'Lucas Brown / Timo Legout',
#     'opponentRank': ' (10/-)',
#     'outcome': 'L',
#     'score': 'Loss 6-7 (3-7)',
#     'player1': 'A. Hoogmartens',
#     'player2': 'Giacomo Revelli',
#     'ranking': '-/-'},
#    {'position': '2',
#     'tournamentTeam': '',
#     'opponent': 'Jonah Braswell / Sebastian Gorzny',
#     'opponentRank': ' (66/-)',
#     'outcome': 'L',
#     'score': 'Loss 4-6',
#     'player1': 'Spencer Johnson',
#     'player2': 'Aadarsh Tripathi',
#     'ranking': '-/-'},
#    {'position': '3',
#     'tournamentTeam': '',
#     'opponent': 'Pierre-Yves Bailly / Sebastian Eriksson',
#     'opponentRank': ' (81/-)',
#     'outcome': 'W',
#     'score': 'Won 7-5',
#     'player1': 'Gianluca Ballotta',
#     'player2': 'Emon van Loben Sels',
#     'ranking': '-/-'}],
#   'doublesTeams': [{'name': 'A. Hoogmartens|Giacomo Revelli',
#     'oldName': None,
#     'playerFirstLastName': None,
#     'checkName': None,
#     'nameFromStats': None,
#     'uniform': '2|5',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': None,
#     'singles': None,
#     'doubles': {'tournament': False,
#      'ranknat': '10',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '1',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Aadarsh Tripathi|Spencer Johnson',
#     'oldName': None,
#     'playerFirstLastName': None,
#     'checkName': None,
#     'nameFromStats': None,
#     'uniform': '6|3',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': None,
#     'singles': None,
#     'doubles': {'tournament': False,
#      'ranknat': '66',
#      'rankreg': '0',
#      'lost': '1',
#      'pair': '2',
#      'tied': '0',
#      'won': '0'}},
#    {'name': 'Emon van Loben Sels|Gianluca Ballotta',
#     'oldName': None,
#     'playerFirstLastName': None,
#     'checkName': None,
#     'nameFromStats': None,
#     'uniform': '7|1',
#     'rosterPlayerId': None,
#     'playerImageUrl': None,
#     'playerUrl': None,
#     'gamePlayed': None,
#     'singles': None,
#     'doubles': {'tournament': False,
#      'ranknat': '81',
#      'rankreg': '0',
#      'lost': '0',
#      'pair': '3',
#      'tied': '0',
#      'won': '1'}}],
#   'oldDate': None,
#   'gameTime': None,
#   'tournament': False,
#   'tournamentName': None,
#   'location': None,
#   'overallRecord': '19-9',
#   'confRecord': '0-0',
#   'thisTeamWon': False,
#   'score': None,
#   'rank': None,
#   'ranknat': '16',
#   'rankreg': '0',
#   'gameDate': None,
#   'gameOpponent': None,
#   'boxscoreUrl': None,
#   'gameOpponentAbbreviation': None,
#   'gameOpponentScore': None,
#   'isAtHome': False,
#   'atNeutral': False,
#   'atConferenceGame': False,
#   'gameId': None,
#   'gameScore': None,
#   'winOrLoss': None},
#  'singles': [{'matchNum': '1',
#    'order': '2',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '4',
#    'name1': 'Quan, Rudy',
#    'rosterId1': '14692',
#    'playerUrl1': '/sports/mens-tennis/roster/rudy-quan/14692',
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '5',
#    'set2': '2',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '20',
#    'rankreg': '',
#    'rank': ' (20/-)',
#    'isWinner': '0'},
#   {'matchNum': '1',
#    'order': '2',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '7',
#    'name1': 'Timo Legout',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '7',
#    'set2': '6',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '1',
#    'rankreg': '',
#    'rank': ' (1/-)',
#    'isWinner': '1'},
#   {'matchNum': '2',
#    'order': '1',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '7',
#    'name1': 'van Loben Sels, Emon',
#    'rosterId1': '14685',
#    'playerUrl1': '/sports/mens-tennis/roster/emon-van-loben-sels/14685',
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '6',
#    'set2': '7',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '7',
#    'tie3': '',
#    'ranknat': '110',
#    'rankreg': '',
#    'rank': ' (110/-)',
#    'isWinner': '1'},
#   {'matchNum': '2',
#    'order': '1',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '6',
#    'name1': 'Sebastian Gorzny',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '3',
#    'set2': '6',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '2',
#    'tie3': '',
#    'ranknat': '26',
#    'rankreg': '',
#    'rank': ' (26/-)',
#    'isWinner': '0'},
#   {'matchNum': '3',
#    'order': '4',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '9',
#    'name1': 'Bigun, Kaylan',
#    'rosterId1': '15117',
#    'playerUrl1': '/sports/mens-tennis/roster/kaylan-bigun/15117',
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '4',
#    'set2': '4',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '',
#    'rankreg': '',
#    'rank': '',
#    'isWinner': '0'},
#   {'matchNum': '3',
#    'order': '4',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '1',
#    'name1': 'Pierre-Yves Bailly',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '6',
#    'set2': '6',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '54',
#    'rankreg': '',
#    'rank': ' (54/-)',
#    'isWinner': '1'},
#   {'matchNum': '4',
#    'order': '3',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '3',
#    'name1': 'Johnson, Spencer',
#    'rosterId1': '14682',
#    'playerUrl1': '/sports/mens-tennis/roster/spencer-johnson/14682',
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '4',
#    'set2': '4',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '35',
#    'rankreg': '',
#    'rank': ' (35/-)',
#    'isWinner': '0'},
#   {'matchNum': '4',
#    'order': '3',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '5',
#    'name1': 'Sebastian Eriksson',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '6',
#    'set2': '6',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '',
#    'rankreg': '',
#    'rank': '',
#    'isWinner': '1'},
#   {'matchNum': '5',
#    'order': '0',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '6',
#    'name1': 'Tripathi, Aadarsh',
#    'rosterId1': '14684',
#    'playerUrl1': '/sports/mens-tennis/roster/aadarsh-tripathi/14684',
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '6',
#    'set2': '1',
#    'set3': '0',
#    'set4': '',
#    'set5': '',
#    'tie1': '7',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '116',
#    'rankreg': '',
#    'rank': ' (116/-)',
#    'isWinner': '0'},
#   {'matchNum': '5',
#    'order': '0',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '2',
#    'name1': 'Jonah Braswell',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '7',
#    'set2': '2',
#    'set3': '95',
#    'set4': '',
#    'set5': '',
#    'tie1': '9',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '72',
#    'rankreg': '',
#    'rank': ' (72/-)',
#    'isWinner': '0'},
#   {'matchNum': '6',
#    'order': '0',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '5',
#    'name1': 'Revelli, Giacomo',
#    'rosterId1': '14683',
#    'playerUrl1': '/sports/mens-tennis/roster/giacomo-revelli/14683',
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '2',
#    'set2': '7',
#    'set3': '0',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '',
#    'rankreg': '',
#    'rank': '',
#    'isWinner': '0'},
#   {'matchNum': '6',
#    'order': '0',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '3',
#    'name1': 'Lucas Brown',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '0',
#    'name2': '0',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '6',
#    'set2': '5',
#    'set3': '95',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '',
#    'rankreg': '',
#    'rank': '',
#    'isWinner': '0'}],
#  'doubles': [{'matchNum': '1',
#    'order': '3',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '2',
#    'name1': 'Hoogmartens, Alexander',
#    'rosterId1': '14681',
#    'playerUrl1': '/sports/mens-tennis/roster/alexander-hoogmartens/14681',
#    'uniform2': '5',
#    'name2': 'Revelli, Giacomo',
#    'rosterId2': '14683',
#    'playerUrl2': '/sports/mens-tennis/roster/giacomo-revelli/14683',
#    'set1': '6',
#    'set2': '',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '3',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '',
#    'rankreg': '',
#    'rank': '',
#    'isWinner': '0'},
#   {'matchNum': '1',
#    'order': '3',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '3',
#    'name1': 'Lucas Brown',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '7',
#    'name2': 'Timo Legout',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '7',
#    'set2': '',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '7',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '10',
#    'rankreg': '',
#    'rank': ' (10/-)',
#    'isWinner': '1'},
#   {'matchNum': '2',
#    'order': '1',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '3',
#    'name1': 'Johnson, Spencer',
#    'rosterId1': '14682',
#    'playerUrl1': '/sports/mens-tennis/roster/spencer-johnson/14682',
#    'uniform2': '6',
#    'name2': 'Tripathi, Aadarsh',
#    'rosterId2': '14684',
#    'playerUrl2': '/sports/mens-tennis/roster/aadarsh-tripathi/14684',
#    'set1': '4',
#    'set2': '',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '',
#    'rankreg': '',
#    'rank': '',
#    'isWinner': '0'},
#   {'matchNum': '2',
#    'order': '1',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '2',
#    'name1': 'Jonah Braswell',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '6',
#    'name2': 'Sebastian Gorzny',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '6',
#    'set2': '',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '66',
#    'rankreg': '',
#    'rank': ' (66/-)',
#    'isWinner': '1'},
#   {'matchNum': '3',
#    'order': '2',
#    'tournament': None,
#    'vh': 'V',
#    'team': 'UCLA',
#    'teamId': 'UCLA',
#    'uniform1': '1',
#    'name1': 'Ballotta, Gianluca',
#    'rosterId1': '14680',
#    'playerUrl1': '/sports/mens-tennis/roster/gianluca-ballotta/14680',
#    'uniform2': '7',
#    'name2': 'van Loben Sels, Emon',
#    'rosterId2': '14685',
#    'playerUrl2': '/sports/mens-tennis/roster/emon-van-loben-sels/14685',
#    'set1': '7',
#    'set2': '',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '',
#    'rankreg': '',
#    'rank': '',
#    'isWinner': '1'},
#   {'matchNum': '3',
#    'order': '2',
#    'tournament': None,
#    'vh': 'H',
#    'team': 'Texas',
#    'teamId': 'TEX',
#    'uniform1': '1',
#    'name1': 'Pierre-Yves Bailly',
#    'rosterId1': None,
#    'playerUrl1': None,
#    'uniform2': '5',
#    'name2': 'Sebastian Eriksson',
#    'rosterId2': None,
#    'playerUrl2': None,
#    'set1': '5',
#    'set2': '',
#    'set3': '',
#    'set4': '',
#    'set5': '',
#    'tie1': '',
#    'tie2': '',
#    'tie3': '',
#    'ranknat': '81',
#    'rankreg': '',
#    'rank': ' (81/-)',
#    'isWinner': '0'}],
#  'finishOrderSingles': '2, 1, 4, 3',
#  'finishOrderDoubles': '2, 3, 1',
#  'thisTeamWon': False,
#  'isNeutral': True,
#  'isALeagueGame': False,
#  'isTournament': False,
#  'homeScore': '4',
#  'visitingScore': '1',
#  'thisTeamScore': '1',
#  'opponentTeamScore': '4',
#  'gameId': None,
#  'winningTeamId': 'TEX',
#  'losingTeamId': 'UCLA',
#  'visitingTeamScore': '1',
#  'visitingTeamName': 'UCLA',
#  'visitingTeamId': 'UCLA',
#  'visitingTeamRecord': '((19-9))',
#  'homeTeamScore': '4',
#  'homeTeamName': 'Texas',
#  'homeTeamId': 'TEX',
#  'homeTeamRecord': '((29-4))',
#  'gameDate': '5/16/2025',
#  'oldDate': '0',
#  'gameTime': '7:00 PM',
#  'opponentTeam': 'Texas',
#  'opponentHistoryPath': '',
#  'periods': [],
#  'periodLabel': None,
#  'periodScoresHome': [],
#  'periodScoresAway': []}

# %%
singles_matches = data.get("singles", [])
singles_matches
# Out:
# [{'matchNum': '1',
#   'order': '2',
#   'tournament': None,
#   'vh': 'V',
#   'team': 'UCLA',
#   'teamId': 'UCLA',
#   'uniform1': '4',
#   'name1': 'Quan, Rudy',
#   'rosterId1': '14692',
#   'playerUrl1': '/sports/mens-tennis/roster/rudy-quan/14692',
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '5',
#   'set2': '2',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '20',
#   'rankreg': '',
#   'rank': ' (20/-)',
#   'isWinner': '0'},
#  {'matchNum': '1',
#   'order': '2',
#   'tournament': None,
#   'vh': 'H',
#   'team': 'Texas',
#   'teamId': 'TEX',
#   'uniform1': '7',
#   'name1': 'Timo Legout',
#   'rosterId1': None,
#   'playerUrl1': None,
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '7',
#   'set2': '6',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '1',
#   'rankreg': '',
#   'rank': ' (1/-)',
#   'isWinner': '1'},
#  {'matchNum': '2',
#   'order': '1',
#   'tournament': None,
#   'vh': 'V',
#   'team': 'UCLA',
#   'teamId': 'UCLA',
#   'uniform1': '7',
#   'name1': 'van Loben Sels, Emon',
#   'rosterId1': '14685',
#   'playerUrl1': '/sports/mens-tennis/roster/emon-van-loben-sels/14685',
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '6',
#   'set2': '7',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '7',
#   'tie3': '',
#   'ranknat': '110',
#   'rankreg': '',
#   'rank': ' (110/-)',
#   'isWinner': '1'},
#  {'matchNum': '2',
#   'order': '1',
#   'tournament': None,
#   'vh': 'H',
#   'team': 'Texas',
#   'teamId': 'TEX',
#   'uniform1': '6',
#   'name1': 'Sebastian Gorzny',
#   'rosterId1': None,
#   'playerUrl1': None,
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '3',
#   'set2': '6',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '2',
#   'tie3': '',
#   'ranknat': '26',
#   'rankreg': '',
#   'rank': ' (26/-)',
#   'isWinner': '0'},
#  {'matchNum': '3',
#   'order': '4',
#   'tournament': None,
#   'vh': 'V',
#   'team': 'UCLA',
#   'teamId': 'UCLA',
#   'uniform1': '9',
#   'name1': 'Bigun, Kaylan',
#   'rosterId1': '15117',
#   'playerUrl1': '/sports/mens-tennis/roster/kaylan-bigun/15117',
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '4',
#   'set2': '4',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '',
#   'rankreg': '',
#   'rank': '',
#   'isWinner': '0'},
#  {'matchNum': '3',
#   'order': '4',
#   'tournament': None,
#   'vh': 'H',
#   'team': 'Texas',
#   'teamId': 'TEX',
#   'uniform1': '1',
#   'name1': 'Pierre-Yves Bailly',
#   'rosterId1': None,
#   'playerUrl1': None,
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '6',
#   'set2': '6',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '54',
#   'rankreg': '',
#   'rank': ' (54/-)',
#   'isWinner': '1'},
#  {'matchNum': '4',
#   'order': '3',
#   'tournament': None,
#   'vh': 'V',
#   'team': 'UCLA',
#   'teamId': 'UCLA',
#   'uniform1': '3',
#   'name1': 'Johnson, Spencer',
#   'rosterId1': '14682',
#   'playerUrl1': '/sports/mens-tennis/roster/spencer-johnson/14682',
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '4',
#   'set2': '4',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '35',
#   'rankreg': '',
#   'rank': ' (35/-)',
#   'isWinner': '0'},
#  {'matchNum': '4',
#   'order': '3',
#   'tournament': None,
#   'vh': 'H',
#   'team': 'Texas',
#   'teamId': 'TEX',
#   'uniform1': '5',
#   'name1': 'Sebastian Eriksson',
#   'rosterId1': None,
#   'playerUrl1': None,
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '6',
#   'set2': '6',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '',
#   'rankreg': '',
#   'rank': '',
#   'isWinner': '1'},
#  {'matchNum': '5',
#   'order': '0',
#   'tournament': None,
#   'vh': 'V',
#   'team': 'UCLA',
#   'teamId': 'UCLA',
#   'uniform1': '6',
#   'name1': 'Tripathi, Aadarsh',
#   'rosterId1': '14684',
#   'playerUrl1': '/sports/mens-tennis/roster/aadarsh-tripathi/14684',
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '6',
#   'set2': '1',
#   'set3': '0',
#   'set4': '',
#   'set5': '',
#   'tie1': '7',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '116',
#   'rankreg': '',
#   'rank': ' (116/-)',
#   'isWinner': '0'},
#  {'matchNum': '5',
#   'order': '0',
#   'tournament': None,
#   'vh': 'H',
#   'team': 'Texas',
#   'teamId': 'TEX',
#   'uniform1': '2',
#   'name1': 'Jonah Braswell',
#   'rosterId1': None,
#   'playerUrl1': None,
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '7',
#   'set2': '2',
#   'set3': '95',
#   'set4': '',
#   'set5': '',
#   'tie1': '9',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '72',
#   'rankreg': '',
#   'rank': ' (72/-)',
#   'isWinner': '0'},
#  {'matchNum': '6',
#   'order': '0',
#   'tournament': None,
#   'vh': 'V',
#   'team': 'UCLA',
#   'teamId': 'UCLA',
#   'uniform1': '5',
#   'name1': 'Revelli, Giacomo',
#   'rosterId1': '14683',
#   'playerUrl1': '/sports/mens-tennis/roster/giacomo-revelli/14683',
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '2',
#   'set2': '7',
#   'set3': '0',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '',
#   'rankreg': '',
#   'rank': '',
#   'isWinner': '0'},
#  {'matchNum': '6',
#   'order': '0',
#   'tournament': None,
#   'vh': 'H',
#   'team': 'Texas',
#   'teamId': 'TEX',
#   'uniform1': '3',
#   'name1': 'Lucas Brown',
#   'rosterId1': None,
#   'playerUrl1': None,
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '6',
#   'set2': '5',
#   'set3': '95',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '',
#   'rankreg': '',
#   'rank': '',
#   'isWinner': '0'}]

# %%
singles_completed_order = data.get("finishOrderSingles", [])
singles_completed_order
# Out:
# '2, 1, 4, 3'

# %%
singles_clinched = int(singles_completed_order[-1] if singles_completed_order else 0)
singles_clinched
# Out:
# 3

# %%
singles_matches[0].get("matchNum", "").strip()
# Out:
# '1'

# %%
list(range(0, len(singles_matches), 2))
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
singles_matches[0:2]
# Out:
# [{'matchNum': '1',
#   'order': '2',
#   'tournament': None,
#   'vh': 'V',
#   'team': 'UCLA',
#   'teamId': 'UCLA',
#   'uniform1': '4',
#   'name1': 'Quan, Rudy',
#   'rosterId1': '14692',
#   'playerUrl1': '/sports/mens-tennis/roster/rudy-quan/14692',
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '5',
#   'set2': '2',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '20',
#   'rankreg': '',
#   'rank': ' (20/-)',
#   'isWinner': '0'},
#  {'matchNum': '1',
#   'order': '2',
#   'tournament': None,
#   'vh': 'H',
#   'team': 'Texas',
#   'teamId': 'TEX',
#   'uniform1': '7',
#   'name1': 'Timo Legout',
#   'rosterId1': None,
#   'playerUrl1': None,
#   'uniform2': '0',
#   'name2': '0',
#   'rosterId2': None,
#   'playerUrl2': None,
#   'set1': '7',
#   'set2': '6',
#   'set3': '',
#   'set4': '',
#   'set5': '',
#   'tie1': '',
#   'tie2': '',
#   'tie3': '',
#   'ranknat': '1',
#   'rankreg': '',
#   'rank': ' (1/-)',
#   'isWinner': '1'}]

# %%
# Helper Function: Format Name
def format_name(name):

    if isinstance(name, str) and ',' in name:
        return " ".join(s.strip() for s in name.split(",")[::-1])
    return name

# %%
# Helper Function to Create Score
def build_tennis_score(match1, match2):

    score_parts = []

    for i in range(1, 4):  # set1 to set3
        set_key = f'set{i}'
        tie_key = f'tie{i}'

        set1_score = match1.get(set_key)
        set2_score = match2.get(set_key)

        # Unfinished matches, don't append/continue function
        if str(set1_score) == '95' or str(set2_score) == '95':
            continue

        # Skip if both scores are missing
        if not set1_score or not set2_score:
            continue

        set_score = f"{set1_score}-{set2_score}"

        # Handle tiebreak
        tie1 = match1.get(tie_key)
        tie2 = match2.get(tie_key)

        if tie1 is not None and tie2 is not None:
            try:
                tie1 = int(tie1)
                tie2 = int(tie2)

                if (set_score == '7-6') or (set_score == '6-7'):
                    # Add the **loser's** tiebreak score in parentheses
                    tiebreak_loser_score = str(min(tie1, tie2))
                    set_score += f"({tiebreak_loser_score})"
            except ValueError:
                pass  # Ignore invalid tiebreak data

        score_parts.append(set_score)

    return ", ".join(score_parts)

# %%
date = data.get('gameDate')
home_team_record = data.get('homeTeamRecord').strip("()")
away_team_record = data.get('visitingTeamRecord').strip("()")

# %%
# Create empty dictionary
player_pairs = []

for i in range(0, len(singles_matches), 2):
    singles_number = int(singles_matches[i]['matchNum'])
    order_finished = singles_matches[i]['order']
    is_clinched = singles_number == singles_clinched
    player1_school = singles_matches[i]['team']
    player2_school = singles_matches[i+1]['team']
    player1_name = format_name(singles_matches[i]['name1'])
    player2_name = format_name(singles_matches[i+1]['name1'])
    score = build_tennis_score(singles_matches[i], singles_matches[i+1])

    if singles_matches[i]['isWinner'] == '1':
        winner = player1_name
    elif singles_matches[i+1]['isWinner'] == '1':
        winner = player2_name
    elif singles_matches[i]['isWinner'] == '0' and singles_matches[i+1]['isWinner'] == '0':
        winner = 'Unfinished'
    else:
        winner = None



    player_pairs.append({
                        'singles_number': singles_number,
                        'order_finished': order_finished,
                        'clincher': is_clinched,
                        'player1_school': player1_school,
                        'player2_school': player2_school,
                        'player1_name': player1_name, 
                        'player2_name': player2_name,
                        'score': score,
                        'match_winner': winner,
                        'date': date,
                        'home_team_record': home_team_record,
                        'away_team_record': away_team_record
                         })
                         

# Convert to DataFrame
df_pairs = pd.DataFrame(player_pairs)

# %%
for url in df['boxScore']:
    print(url)
# Out:
# https://uclabruins.com/api/v2/Stats/boxscore/34034
# https://uclabruins.com/api/v2/Stats/boxscore/34033
# https://uclabruins.com/api/v2/Stats/boxscore/34217
# https://uclabruins.com/api/v2/Stats/boxscore/34032
# https://uclabruins.com/api/v2/Stats/boxscore/34211
# https://uclabruins.com/api/v2/Stats/boxscore/34210
# https://uclabruins.com/api/v2/Stats/boxscore/34031
# https://uclabruins.com/api/v2/Stats/boxscore/34030
# https://uclabruins.com/api/v2/Stats/boxscore/34029
# https://uclabruins.com/api/v2/Stats/boxscore/34028
# https://uclabruins.com/api/v2/Stats/boxscore/34027
# https://uclabruins.com/api/v2/Stats/boxscore/34026
# https://uclabruins.com/api/v2/Stats/boxscore/34025
# https://uclabruins.com/api/v2/Stats/boxscore/34020
# https://uclabruins.com/api/v2/Stats/boxscore/34024
# https://uclabruins.com/api/v2/Stats/boxscore/34023
# https://uclabruins.com/api/v2/Stats/boxscore/34022
# https://uclabruins.com/api/v2/Stats/boxscore/34021
# https://uclabruins.com/api/v2/Stats/boxscore/34019
# https://uclabruins.com/api/v2/Stats/boxscore/34018
# None
# https://uclabruins.com/api/v2/Stats/boxscore/34016
# https://uclabruins.com/api/v2/Stats/boxscore/34169
# https://uclabruins.com/api/v2/Stats/boxscore/34014
# https://uclabruins.com/api/v2/Stats/boxscore/34013
# https://uclabruins.com/api/v2/Stats/boxscore/34012
# https://uclabruins.com/api/v2/Stats/boxscore/34011
# https://uclabruins.com/api/v2/Stats/boxscore/34010
# https://uclabruins.com/api/v2/Stats/boxscore/34008
# None
# None
# None
# None
# None
# None
# https://uclabruins.com/api/v2/Stats/boxscore/33510
# https://uclabruins.com/api/v2/Stats/boxscore/33249
# https://uclabruins.com/api/v2/Stats/boxscore/33489
# https://uclabruins.com/api/v2/Stats/boxscore/33448
# https://uclabruins.com/api/v2/Stats/boxscore/32975
# https://uclabruins.com/api/v2/Stats/boxscore/33248
# None
# https://uclabruins.com/api/v2/Stats/boxscore/33183
# https://uclabruins.com/api/v2/Stats/boxscore/33114
# https://uclabruins.com/api/v2/Stats/boxscore/33247

# %% [markdown]
# ## Completed Function

# %% [markdown]
# ### Load Packages

# %%
import requests
import pandas as pd

# %% [markdown]
# ##### Helper Functions

# %%
# Helper Function: Format Name
def format_name(name):

    if isinstance(name, str) and ',' in name:
        return " ".join(s.strip() for s in name.split(",")[::-1])
    return name

# %%
# Helper Function to Create Score
def build_tennis_score(match1, match2):

    score_parts = []

    for i in range(1, 4):  # set1 to set3
        set_key = f'set{i}'
        tie_key = f'tie{i}'

        set1_score = match1.get(set_key)
        set2_score = match2.get(set_key)

        # Unfinished matches, don't append/continue function
        if str(set1_score) == '95' or str(set2_score) == '95':
            continue

        # Skip if both scores are missing
        if not set1_score or not set2_score:
            continue

        set_score = f"{set1_score}-{set2_score}"

        # Handle tiebreak
        tie1 = match1.get(tie_key)
        tie2 = match2.get(tie_key)

        if tie1 is not None and tie2 is not None:
            try:
                tie1 = int(tie1)
                tie2 = int(tie2)

                if (set_score == '7-6') or (set_score == '6-7'):
                    # Add the **loser's** tiebreak score in parentheses
                    tiebreak_loser_score = str(min(tie1, tie2))
                    set_score += f"({tiebreak_loser_score})"
            except ValueError:
                pass  # Ignore invalid tiebreak data

        score_parts.append(set_score)

    return ", ".join(score_parts)

# %%
def ucla_bruins(team, year):
    if team.lower() == 'w':
        url = "https://uclabruins.com/api/v2/EventsResults/results?sportId=21&$pageIndex=0&$pageSize=50"
    elif team.lower() == 'm':
        url =  "https://uclabruins.com/api/v2/EventsResults/results?sportId=9&$pageIndex=0&$pageSize=50"

    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        all_games = []

        for game in data.get("items", []):
            game_data = {}
            game_data["date"] = game.get("date", "No date available").split("T")[0]
            game_data["location"] = game.get("location", "No location available")
            
            opponent_title = game.get("opponent", {}).get("title", "")
            opponent_parts = opponent_title.split()

            # Only assign seed if it exists
            seed = opponent_parts[1] if len(opponent_parts) > 1 else None
            game_data["opponent_seed"] = seed if seed and seed.isdigit() else None

            game_data["isConference"] = game.get("isConference")
            game_data["tournament"] = game.get("tournament")
            
            result = game.get("result", {}) or {}
            boxScore = result.get("boxScore")
            if isinstance(boxScore, str) and boxScore.startswith("/"):
                boxScore = "https://uclabruins.com/api/v2/Stats/boxscore/" + boxScore.split("=")[-1]
            game_data["boxScore"] = boxScore

            game_data["overallScore"] = str(result.get("teamScore")) + '-' + str(result.get("opponentScore"))

            lineScores = result.get("lineScores", {}) or {}

            winner_code = lineScores.get("game_winner")
            winner_label = {'H': 'home', 'A': 'away'}.get(winner_code, None)

            game_data["game_winner_label"] = winner_label   

            game_data["this_team_is_home_team"] = lineScores.get("this_team_is_home_team")
            game_data["home_full_name"] = lineScores.get("home_full_name")
            game_data["away_full_name"] = lineScores.get("away_full_name")
            
            facility = game.get("gameFacility", {}) or {}
            game_data["facility_id"] = facility.get("id")
            game_data["facility_location"] = facility.get("title")

            all_games.append(game_data)

        df = pd.DataFrame(all_games)
    else:
        print(f"Error: Unable to fetch data (Status Code: {response.status_code})")

    ### Parse each individual URL

    all_matches = []

    for url in df['boxScore'].dropna():
        response = requests.get(url, timeout=10) 
        response.raise_for_status() 
        data = response.json()
        singles_matches = data.get("singles", [])

        date = data.get('gameDate')
        home_team_record = data.get('homeTeamRecord').strip("()")
        away_team_record = data.get('visitingTeamRecord').strip("()")
        
        # Grab singles number clinched
        singles_completed_order = data.get("finishOrderSingles", [])
        singles_clinched = int(singles_completed_order[-1] if singles_completed_order else 0)

        # Create empty dictionary
        player_pairs = []
            
        for i in range(0, len(singles_matches), 2):
            singles_number = int(singles_matches[i]['matchNum'])
            order_finished = singles_matches[i]['order']
            is_clinched = singles_number == singles_clinched
            player1_school = singles_matches[i]['team']
            player2_school = singles_matches[i+1]['team']
            player1_name = format_name(singles_matches[i]['name1'])
            player2_name = format_name(singles_matches[i+1]['name1'])
            score = build_tennis_score(singles_matches[i], singles_matches[i+1])

            if singles_matches[i]['isWinner'] == '1':
                winner = player1_name
            elif singles_matches[i+1]['isWinner'] == '1':
                winner = player2_name
            elif singles_matches[i]['isWinner'] == '0' and singles_matches[i+1]['isWinner'] == '0':
                winner = 'Unfinished'
            else:
                winner = None

            player_pairs.append({
                                'date': date,
                                'singles_number': singles_number,
                                'order_finished': order_finished,
                                'clincher': is_clinched,
                                'player1_school': player1_school,
                                'player2_school': player2_school,
                                'player1_name': player1_name, 
                                'player2_name': player2_name,
                                'score': score,
                                'match_winner': winner,
                                'home_team_record': home_team_record,
                                'away_team_record': away_team_record
                                })
                            
        match_df = pd.DataFrame(player_pairs)
        all_matches.append(match_df)

    df_all = pd.concat(all_matches, ignore_index=True)

    # Choose the date
    df_all['date'] = pd.to_datetime(df_all['date'], errors='coerce')
    output_df = df_all[df_all['date'].dt.year == year]

    # Output Dataframe
    output_df.to_csv(f'../data/mens/matches_{year}.csv', index=False)

    return print(f'Saved matches_{year}.csv')

# %% [markdown]
# ### Output Csv

# %%
ucla_bruins('m', 2025)
# Out:
# Saved matches_2025.csv

# %%
# all_matches = []


# for url in df['boxScore'].dropna():
#     response = requests.get(url, timeout=10) 
#     response.raise_for_status() 
#     data = response.json()
#     singles_matches = data.get("singles", [])

#     date = data.get('gameDate')
#     home_team_record = data.get('homeTeamRecord').strip("()")
#     away_team_record = data.get('visitingTeamRecord').strip("()")
    
#     # Grab singles number clinched
#     singles_completed_order = data.get("finishOrderSingles", [])
#     singles_clinched = int(singles_completed_order[-1] if singles_completed_order else 0)

#     # Create empty dictionary
#     player_pairs = []
        
#     for i in range(0, len(singles_matches), 2):
#         singles_number = int(singles_matches[i]['matchNum'])
#         order_finished = singles_matches[i]['order']
#         is_clinched = singles_number == singles_clinched
#         player1_school = singles_matches[i]['team']
#         player2_school = singles_matches[i+1]['team']
#         player1_name = format_name(singles_matches[i]['name1'])
#         player2_name = format_name(singles_matches[i+1]['name1'])
#         score = build_tennis_score(singles_matches[i], singles_matches[i+1])

#         if singles_matches[i]['isWinner'] == '1':
#             winner = player1_name
#         elif singles_matches[i+1]['isWinner'] == '1':
#             winner = player2_name
#         elif singles_matches[i]['isWinner'] == '0' and singles_matches[i+1]['isWinner'] == '0':
#             winner = 'Unfinished'
#         else:
#             winner = None

#         player_pairs.append({
#                             'date': date,
#                             'singles_number': singles_number,
#                             'order_finished': order_finished,
#                             'clincher': is_clinched,
#                             'player1_school': player1_school,
#                             'player2_school': player2_school,
#                             'player1_name': player1_name, 
#                             'player2_name': player2_name,
#                             'score': score,
#                             'match_winner': winner,
#                             'home_team_record': home_team_record,
#                             'away_team_record': away_team_record
#                             })
                         
#     match_df = pd.DataFrame(player_pairs)
#     all_matches.append(match_df)

# df_all = pd.concat(all_matches, ignore_index=True)
# df_all

# %%
# df_all = pd.concat(all_matches, ignore_index=True)
# df_all
