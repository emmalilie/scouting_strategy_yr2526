# %% [markdown]
# ## Match Index Notebook
# This Notebook is for the Index Page of the Season Reports

# %% [markdown]
# ### Load Packages

# %%
import pandas as pd
import re
import os

import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ### Read Data

# %%
# Dropdown with a non-valid default option
choose_player_dropdown = widgets.Dropdown(
    options=['-- Select --', 'Rudy Quan', 'Emon Van Loben Sels', 'Kaylan Bigun', 'Alexander Hoogmartens', 
             'Spencer Johnson', 'Aadarsh Tripathi', 'Giacomo Revelli', 'Gianluca Ballotta'],
    value='-- Select --',
    description='Category:'
)

display(choose_player_dropdown)

# Set School
school = 'University of California, Los Angeles'
# Out:
# Dropdown(description='Category:', options=('-- Select --', 'Rudy Quan', 'Emon Van Loben Sels', 'Kaylan Bigun',…

# %%
# Check selection before proceeding
if choose_player_dropdown.value == '-- Select --':
    raise ValueError("Please choose a valid category from the dropdown menu in the previous cell before proceeding.")

# If valid, use the value
player_name = choose_player_dropdown.value

# %%
# Subset 2024-2025 Season Matches!
matches = pd.read_csv('../../data/mens/match_results.csv')

# Change Date Format
matches['Date'] = pd.to_datetime(matches['Date'])

# Function to Filter by Player and School Matches Only
def filter_player(data, player_name):

    # Filter for player_name
    data = data[(data['Player1'] == player_name) | (data['Player2'] == player_name)]

    # Filter for only school events
    data = data[data['Event Name'].str.startswith(('Dual Match', '2025 ITA', '2025-26 NCAA Division'), na=False)]
    return data


matches = filter_player(matches, player_name)

# %%
matches
# Out:
#                                              Event Name       Date  \
# 1830  Dual Match: University of San Diego vs Univers... 2026-05-01
# 1831       Dual Match: UCLA vs Arizona State University 2026-04-30
# 1832  Dual Match: University of California, Los Ange... 2026-04-30
# 1833  Dual Match: Michigan State University vs Unive... 2026-04-23
# 1834  Dual Match: University of California, Los Ange... 2026-04-22
# 1835       Dual Match: UCLA vs University of Washington 2026-04-18
# 1836  Dual Match: University of California, Los Ange... 2026-04-16
# 1837  Dual Match: University of Illinois vs Universi... 2026-04-10
# 1838  Dual Match: Ohio State University vs Universit... 2026-04-03
# 1839  Dual Match: University of California Los Angel... 2026-03-26
# 1840  Dual Match: University of California, Los Ange... 2026-03-21
# 1841  Dual Match: University of California, Los Ange... 2026-03-19
# 1842  Dual Match: University of California, Los Ange... 2026-03-12
# 1843  Dual Match: University of California, Los Ange... 2026-03-07
# 1844  Dual Match: University of California, Los Ange... 2026-03-05
# 1845  Dual Match: University of California, Los Ange... 2026-02-25
# 1846  Dual Match: University of Southern California ... 2026-02-20
# 1847  Dual Match: University of California, Los Ange... 2026-02-14
# 1848  Dual Match: University of California, Los Ange... 2026-02-06
# 1849  Dual Match: University of California, Los Ange... 2026-01-31
# 1850  Dual Match: Stanford University vs University ... 2026-01-30
# 1851  Dual Match: University of California, Santa Ba... 2026-01-23
# 1852  Dual Match: University of New Mexico vs Univer... 2026-01-22
# 1853  Dual Match: University of California, Irvine v... 2026-01-16
# 1855  2025 ITA DI Men's Southwest Regional Champions... 2025-10-20
# 1856  2025 ITA DI Men's Southwest Regional Champions... 2025-10-20
# 1857  2025 ITA DI Men's Southwest Regional Champions... 2025-10-20
# 1858  2025 ITA DI Men's Southwest Regional Champions... 2025-10-20
# 1859  2025 ITA DI Men's Southwest Regional Champions... 2025-10-20
# 1879  Dual Match: University of California, Los Ange... 2025-05-15
# 1880  Dual Match: University of Southern California ... 2025-05-08
# 1881  Dual Match: University of California, Los Ange... 2025-05-02
# 1882  Dual Match: University of California, Santa Ba... 2025-05-01
# 1883  Dual Match: University of California, Los Ange... 2025-04-26
# 1884  Dual Match: Michigan State University vs Unive... 2025-04-25
# 1885  Dual Match: University of Michigan vs Universi... 2025-04-24
# 1886  Dual Match: University of California, Los Ange... 2025-04-19
# 1887  Dual Match: University of California, Los Ange... 2025-04-17
# 1888  Dual Match: Michigan State University vs Unive... 2025-04-12
# 1889  Dual Match: University of California, Los Ange... 2025-04-10
# 1890  Dual Match: University of California, Los Ange... 2025-04-05
# 1891  Dual Match: University of California, Los Ange... 2025-04-03
# 1892  Dual Match: Ohio State University vs Universit... 2025-04-03
# 1893  Dual Match: University of California, Los Ange... 2025-03-31
# 1894  Dual Match: University of Washington vs Univer... 2025-03-29
# 1895  Dual Match: University of Oregon vs University... 2025-03-28
# 1896  Dual Match: University of California, Los Ange... 2025-03-22
# 1897  Dual Match: University of California, Los Ange... 2025-03-20
# 1900  Dual Match: Purdue University vs University of... 2025-03-08
# 1901  Dual Match: Indiana University vs University o... 2025-03-06
# 1903  Dual Match: University of Southern California ... 2025-02-21
# 1904  Dual Match: Pepperdine University vs Universit... 2025-02-15
# 1905  Dual Match: University of California, Berkeley... 2025-01-31
# 1906  Dual Match: University of Georgia vs Universit... 2025-01-25
# 1907  Dual Match: University of California, Los Ange... 2025-01-24
# 1908  Dual Match: University of San Diego vs Univers... 2025-01-19
# 1909  Dual Match: University of California, Los Ange... 2025-01-16
# 2392  Dual Match: University of California, Los Ange... 2025-01-16
# 3485  2025 ITA DI Men's Southwest Regional Champions... 2025-10-20
#
#                    Player1  Player1 UTR                    Player2  \
# 1830    Manvydas Balciunas        13.41                  Rudy Quan
# 1831             Rudy Quan        13.54              Mathis Bondaz
# 1832             Rudy Quan        13.54               Shu Matsuoka
# 1833        Matthew Forbes        13.60                  Rudy Quan
# 1834             Rudy Quan        13.54             Maxwell Exsted
# 1835             Rudy Quan        13.54              Soham Purohit
# 1836             Rudy Quan        13.54       Vlad Cristian Breazu
# 1837  Kenta (2004) Miyoshi        13.80                  Rudy Quan
# 1838       Preston Stearns        13.51                  Rudy Quan
# 1839         Bjorn Swenson        13.31                  Rudy Quan
# 1840             Rudy Quan        13.54             Nikolay Sysoev
# 1841             Rudy Quan        13.54            Patrik Meszaros
# 1842         Nathan Trouve        13.40                  Rudy Quan
# 1843             Rudy Quan        13.54           Henrik Villanger
# 1844             Rudy Quan        13.54         Jip Van Assendelft
# 1845             Rudy Quan        13.54            Vincent Marysko
# 1846             Rudy Quan        13.54              Nathan Trouve
# 1847             Rudy Quan        13.54           Marko Maksimovic
# 1848             Rudy Quan        13.54         Maximilian Homberg
# 1849             Rudy Quan        13.54                Tiago Silva
# 1850             Rudy Quan        13.54            Alexander Chang
# 1851             LUCCA LIU        13.53                  Rudy Quan
# 1852             Rudy Quan        13.54  Dario Alexandru Ciobotaru
# 1853             Rudy Quan        13.54                Tal Goodman
# 1855             Rudy Quan        13.54           Aadarsh Tripathi
# 1856             Rudy Quan        13.54          Charlie Underwood
# 1857             Rudy Quan        13.54                Jelani Sarr
# 1858             Rudy Quan        13.54           Filip Gustafsson
# 1859             Rudy Quan        13.54             Aleksa Pisaric
# 1879           Timo Legout        13.79                  Rudy Quan
# 1880             Rudy Quan        13.54                 Peter Makk
# 1881    Carl Emil Overbeck        14.04                  Rudy Quan
# 1882             Rudy Quan        13.54           Gianluca Brunkow
# 1883             Aidan Kim        13.76                  Rudy Quan
# 1884             Rudy Quan        13.54         Aristotelis Thanos
# 1885             Rudy Quan        13.54            William Cooksey
# 1886             Rudy Quan        13.54             Calvin Mueller
# 1887      Michael Minasyan        13.11                  Rudy Quan
# 1888             Rudy Quan        13.54                 Ozan Baris
# 1889             Rudy Quan        13.54            William Cooksey
# 1890             Rudy Quan        13.54               Charl Morgan
# 1891     Alexander Bernard        13.29                  Rudy Quan
# 1892     Alexander Bernard        13.29                  Rudy Quan
# 1893            Peter Makk        14.01                  Rudy Quan
# 1894             Rudy Quan        13.54         César Bouchelaghem
# 1895             Rudy Quan        13.54            Lenn Luemkemann
# 1896       Saiprakash Goli         0.00                  Rudy Quan
# 1897  Kenta (2004) Miyoshi        13.80                  Rudy Quan
# 1900             Rudy Quan        13.54          Aleksa Krivokapic
# 1901             Rudy Quan        13.54              Deacon Thomas
# 1903             Rudy Quan        13.54                 Peter Makk
# 1904         Edward Winter        13.73                  Rudy Quan
# 1905    Carl Emil Overbeck        14.04                  Rudy Quan
# 1906             Rudy Quan        13.54                 Ryan Colby
# 1907         Jerry Roddick        13.44                  Rudy Quan
# 1908             Rudy Quan        13.54                  Iiro Vasa
# 1909             Rudy Quan        13.54                Andy Nguyen
# 2392             Rudy Quan        13.54                Andy Nguyen
# 3485             Rudy Quan        13.54           Aadarsh Tripathi
#
#       Player2 UTR              Score     Searched Name
# 1830        13.54   7-6(3), 3-6, 1-0         Rudy Quan
# 1831        13.10           6-3, 6-0         Rudy Quan
# 1832        13.02           6-3, 6-0         Rudy Quan
# 1833        13.54           6-3, 6-4         Rudy Quan
# 1834        13.38           6-1, 6-4         Rudy Quan
# 1835        13.00           6-4, 6-3         Rudy Quan
# 1836        13.32           6-2, 6-3         Rudy Quan
# 1837        13.54      6-3, 5-7, 1-1         Rudy Quan
# 1838        13.54   6-1, 6-7(7), 1-1         Rudy Quan
# 1839        13.54      6-3, 2-6, 2-1         Rudy Quan
# 1840        12.00           6-2, 6-1         Rudy Quan
# 1841        13.40  7-5, 4-6, 1-0(12)         Rudy Quan
# 1842        13.54      2-6, 6-4, 6-3         Rudy Quan
# 1843        12.72        7-6(6), 6-3         Rudy Quan
# 1844        12.80      6-1, 4-6, 6-1         Rudy Quan
# 1845        12.93      3-6, 7-6, 7-5         Rudy Quan
# 1846        13.40           7-5, 7-5         Rudy Quan
# 1847        13.14           6-2, 6-2         Rudy Quan
# 1848        13.15      6-0, 3-6, 6-4         Rudy Quan
# 1849        12.96           6-4, 7-5         Rudy Quan
# 1850        13.11           7-6, 5-5         Rudy Quan
# 1851        13.54           6-3, 6-4         Rudy Quan
# 1852        12.70           6-3, 4-1         Rudy Quan
# 1853        12.00           6-2, 6-2         Rudy Quan
# 1855        13.01           6-2, 6-1         Rudy Quan
# 1856        12.00           6-4, 7-5         Rudy Quan
# 1857        12.00      6-2, 5-7, 6-4         Rudy Quan
# 1858        13.38           6-1, 6-4         Rudy Quan
# 1859        13.14           6-4, 6-0         Rudy Quan
# 1879        13.54           7-5, 6-2         Rudy Quan
# 1880        14.01   7-6(4), 3-6, 3-3         Rudy Quan
# 1881        13.54      5-7, 7-5, 6-3         Rudy Quan
# 1882        13.63      5-7, 6-2, 0-1         Rudy Quan
# 1883        13.54        7-6(3), 6-2         Rudy Quan
# 1884        13.85           4-6, 3-1         Rudy Quan
# 1885        12.00           6-3, 5-6         Rudy Quan
# 1886        13.38      3-6, 6-3, 6-1         Rudy Quan
# 1887        13.54           2-6, 6-3         Rudy Quan
# 1888        13.63           6-1, 6-2         Rudy Quan
# 1889        12.00           6-3, 6-3         Rudy Quan
# 1890         0.00           6-3, 6-3         Rudy Quan
# 1891        13.54   7-6(5), 0-6, 3-1         Rudy Quan
# 1892        13.54        7-6(5), 0-6         Rudy Quan
# 1893        13.54           6-4, 6-4         Rudy Quan
# 1894        13.63           6-4, 4-4         Rudy Quan
# 1895        12.00           6-3, 5-3         Rudy Quan
# 1896        13.54           7-5, 3-3         Rudy Quan
# 1897        13.54        7-6(5), 5-1         Rudy Quan
# 1900        13.00   4-6, 6-3, 1-0(3)         Rudy Quan
# 1901        12.00           6-2, 6-4         Rudy Quan
# 1903        14.01           6-2, 6-3         Rudy Quan
# 1904        13.54      4-6, 6-0, 6-2         Rudy Quan
# 1905        13.54   6-7(7), 6-3, 6-4         Rudy Quan
# 1906        13.54           6-2, 6-3         Rudy Quan
# 1907        13.54      6-3, 2-6, 6-3         Rudy Quan
# 1908        13.05        6-3, 7-6(5)         Rudy Quan
# 1909        13.00           6-4, 6-3         Rudy Quan
# 2392        13.00           6-4, 6-3       Andy Nguyen
# 3485        13.01           6-2, 6-1  Aadarsh Tripathi

# %% [markdown]
# ### index_csv() Function

# %% [markdown]
# #### Helper Function to Flip Scores

# %%
# Helper function to flip scores like "7-6(5), 5-7, 6-3"
# Also does not include commas in the final result

def flip_score(score_str, player1):

    if player1 in player_name:
        return score_str.replace(",", "")

    flipped = []
    for set_score in score_str.split(', '):
        match = re.match(r'(\d+)-(\d+)(\(\d+\))?', set_score)
        if match:
            p1, p2, tiebreak = match.groups()
            flipped_score = f"{p2}-{p1}"
            if tiebreak:
                flipped_score += tiebreak
            flipped.append(flipped_score)
        else:
            flipped.append(set_score)  # Preserve unrecognized formats
    else: 
        return ' '.join(flipped)

# %%
# Make Win and Loss --> "W" and "L" AND take into account UNFINISHED matches "UF"
# eg. 6-3 6-3 W  | 3-6 4-6 L  | 2-6 6-5 UF

def determine_result(row):
    score = row['Score']
    if pd.isna(score) or 'UF' in str(score).upper():
        return 'UF'

    sets = score.split(',')
    p1_sets_won = 0
    p2_sets_won = 0
    valid_sets = 0

    for i, set_score in enumerate(sets):
        set_score = set_score.strip()

        # Special case for 10-point tiebreaker in the third set
        if i == len(sets) - 1:  # Check if it is the last set
            match_tb = re.match(r'(1-0|0-1)\((\d+)\)', set_score)
            if match_tb:
                if match_tb.group(1) == '1-0':
                    p1_sets_won += 1
                else:
                    p2_sets_won += 1
                valid_sets += 1
                continue

        # Regular set score matching
        match = re.match(r'(\d+)-(\d+)(\(\d+\))?', set_score)
        if match:
            p1_games, p2_games, tiebreak = match.groups()
            p1_games, p2_games = int(p1_games), int(p2_games)

            # Check if the set is complete (at least 6 games with a difference of 2)
            if (p1_games >= 6 or p2_games >= 6) and abs(p1_games - p2_games) >= 2:
                valid_sets += 1
                if p1_games > p2_games:
                    p1_sets_won += 1
                else:
                    p2_sets_won += 1
            # Check for tiebreak set with 7 games (e.g., 7-6)
            elif (p1_games == 7 or p2_games == 7) and (p1_games >= 6 and p2_games >= 6):
                valid_sets += 1
                if p1_games > p2_games:
                    p1_sets_won += 1
                else:
                    p2_sets_won += 1
            else:
                # Unfinished set if conditions are not met
                return 'UF'
        else:
            # If the format is not recognized, mark as unfinished
            return 'UF'

    # Check if the match is complete based on valid sets won
    if (valid_sets >= 2 and (p1_sets_won == 2 or p2_sets_won == 2)) or (valid_sets >= 3 and (p1_sets_won == 3 or p2_sets_won == 3)):
        if row['Player1'] == player_name:
            return 'W' if p1_sets_won > p2_sets_won else 'L'
        elif row['Player2'] == player_name:
            return 'W' if p2_sets_won > p1_sets_won else 'L'
    return 'UF'

# %%
def index_csv(data, player_name, school):

    # Filter for Player
    df = data[(data['Player1'] == player_name) | (matches['Player2'] == player_name)].copy()
    
    # Extract opponent name from 'Event Name'
    def get_opponent(event):
        if not isinstance(event, str):
            return None
        teams = re.findall(r'vs\s(.+)', event)
        if school in event and teams:
            return teams[0].strip() if school in event.split('vs')[0] else event.split('vs')[0].replace('Dual Match:', '').strip()
        return None

    # Create opponent_school Column
    df['opponent_school'] = df['Event Name'].apply(get_opponent)

    # Create opponent Column
    df['opponent'] = df.apply(lambda row: row['Player2'] if row['Player1'] in player_name 
                                    else (row['Player1'] if row['Player2'] in player_name 
                                    else None
                                    ), axis=1
                                    )
    
    # Make all names to where the only the first letter of each name is capitalized
    # eg. Aristotelis THANOS --> Aristotelis Thanos
    df['opponent'] = df['opponent'].str.title()    

    # Flip the score only if Player 2 is a UCLA player
    df['Score (UCLA Perspective)'] = df.apply(lambda row: flip_score(row['Score'], row['Player1']),
                                                        axis=1)

    # Result column
    df['ucla_result'] = df.apply(determine_result, axis=1)

    # Convert the 'Date' column to datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Make date column to mm/dd/yy format
    # eg. 2025-04-26 --> 04/26/25
    df['Date'] = df['Date'].dt.strftime('%m/%d/%y')
    
    # Final Columns + rename columns
    final_df = df[['opponent_school', 
                   'opponent', 
                   'Score (UCLA Perspective)', 
                   'ucla_result',
                   'Date']].rename(columns={'Score (UCLA Perspective)': 'score',
                                            'ucla_result': 'result',
                                            'Date': 'date'
                                            })

    return final_df

# %% [markdown]
# ### Output Function Result

# %%
matches_cleaned = index_csv(matches, player_name, school)
matches_cleaned

# %%
# Output to csv in index_page folder

player_name_nospace = player_name.replace(' ', '')

# Save the DataFrame to a CSV file
matches_cleaned.to_csv(f'{player_name_nospace}_matches.csv', index=False)

# Split DataFrame into chunks of 15 rows
chunk_size = 15
chunks = [matches_cleaned.iloc[i:i + chunk_size] for i in range(0, len(matches_cleaned), chunk_size)]

# Save each chunk as a separate CSV file
for idx, chunk in enumerate(chunks):
    chunk.to_csv(f'{player_name_nospace}_matches{idx+1}.csv', index=False)
    print(f'{player_name_nospace}_matches{idx+1}.csv' + ' Saved!')
