# %%
import pandas as pd
import re 
import os

os.getcwd() # Print current working directory
# Out:
# '/Users/stephaniepham/Desktop/consulting-spring2025/season_report/return_page'

# %% [markdown]
# Read Data

# %%
os.chdir('../..') # go back two directories
os.getcwd()
# Out:
# '/Users/stephaniepham/Desktop/consulting-spring2025'

# %%
# USER INPUT: Specify Player!
player_name = 'Rudy Quan'
# player_name = 'Kaylan Bigun'
# # player_name = 'Emon Van Loben Sels'
# player_name = 'Alexander Hoogmartens'
# player_name = 'Spencer Johnson'
# player_name = 'Aadarsh Tripathi'
# player_name = 'Giacomo Revelli'
# player_name = 'Gianluca Ballotta'

# %%
combined_data_shots = pd.read_excel(f'data/mens/{player_name}/combined.xlsx', sheet_name='Shots')
combined_data_points = pd.read_excel(f'data/mens/{player_name}/combined.xlsx', sheet_name='Points')
combined_data_games = pd.read_excel(f'data/mens/{player_name}/combined.xlsx', sheet_name='Games')
combined_data_sets = pd.read_excel(f'data/mens/{player_name}/combined.xlsx', sheet_name='Sets')

# %%
# Subset 2024-2025 Season Matches!
mens_results = pd.read_csv('data/mens/mens_results.csv')[:229]

# Change Date Format
mens_results['Date'] = pd.to_datetime(mens_results['Date'])


def filter_player(data, player_name):

    # Filter for player_name
    data = data[(data['Player1'] == player_name) | (data['Player2'] == player_name)]

    # Filter for only school events
    data = data[data['Event Name'].str.startswith(('Dual Match', '2024 ITA', '2024-25 NCAA Division'))]
    return data

mens_results_player = filter_player(mens_results, player_name)

# %%
mens_results_player

# %%
combined = combined_data_shots.merge(combined_data_points[['Point', 'Game', 'Set', 'Match Server', '__source_file__']], 
                          how = 'left', 
                          on = ['Set', 'Game', 'Point', '__source_file__'])[1000:4000]

# %%
# Find All Returning Games
returns = combined[(combined['Match Server'] == 'guest') & (combined['Player'] == player_name) & ((combined['Type'] == 'first_return') | (combined['Type'] == 'second_return'))]

returns
# Out:
#          Player  Shot           Type    Stroke     Spin  Speed (MPH)  Point  \
# 1009  Rudy Quan     2  second_return  Backhand  Topspin    51.582260     37
# 1016  Rudy Quan     2  second_return  Backhand     Flat    71.305695     38
# 1026  Rudy Quan     2   first_return  Backhand  Topspin    40.496258     39
# 1028  Rudy Quan     2   first_return  Backhand  Topspin    50.528534     40
# 1034  Rudy Quan     2   first_return  Backhand    Slice    32.772774     41
# ...         ...   ...            ...       ...      ...          ...    ...
# 3947  Rudy Quan     2   first_return  Forehand     Flat    53.472031     85
# 3951  Rudy Quan     2   first_return  Backhand     Flat    55.458935     86
# 3959  Rudy Quan     2  second_return  Forehand     Flat    77.942482     87
# 3964  Rudy Quan     2   first_return  Forehand  Topspin    61.407204     88
# 3969  Rudy Quan     2  second_return  Backhand     Flat    61.331078     89
#
#       Game  Set Bounce Depth  ...   Hit (x)    Hit (y)   Hit (z)  \
# 1009     8    1         deep  ... -0.028372  24.587389  1.673195
# 1016     8    1         deep  ...  4.543220  26.304169  1.149330
# 1026     8    1        short  ... -1.585526  25.424723  1.853700
# 1028     8    1         deep  ...  4.556429  25.525892  1.048352
# 1034     8    1         deep  ... -0.826689  25.731417  1.620931
# ...    ...  ...          ...  ...       ...        ...       ...
# 3947    15    2          out  ...  2.247430  27.328449  1.033211
# 3951    15    2         deep  ... -1.728403  26.492403  1.157648
# 3959    15    2         deep  ...  2.862678  25.763754  1.210788
# 3964    15    2         deep  ... -5.839761  27.128525  1.075889
# 3969    15    2         deep  ...  5.114884  25.340780  1.423702
#
#           Direction Result Favorited Start Time   Video Time  \
# 1009     inside out     In     False   21:37:04  1439.130005
# 1016  down the line     In     False   21:37:38  1473.880005
# 1026      inside in     In     False   21:38:18  1513.339966
# 1028  down the line     In     False   21:38:40  1535.949951
# 1034     inside out     In     False   21:39:07  1562.339966
# ...             ...    ...       ...        ...          ...
# 3947     inside out    Out     False   22:48:06          NaN
# 3951      inside in     In     False   22:48:22          NaN
# 3959     inside out     In     False   22:49:06          NaN
# 3964  down the line     In     False   22:49:57          NaN
# 3969  down the line     In     False   22:50:37          NaN
#
#                          __source_file__  Match Server
# 1009  RudyQuan_FloridaState_9_23_24.xlsx         guest
# 1016  RudyQuan_FloridaState_9_23_24.xlsx         guest
# 1026  RudyQuan_FloridaState_9_23_24.xlsx         guest
# 1028  RudyQuan_FloridaState_9_23_24.xlsx         guest
# 1034  RudyQuan_FloridaState_9_23_24.xlsx         guest
# ...                                  ...           ...
# 3947    RudyQuan_Pepperdine_2_27_25.xlsx         guest
# 3951    RudyQuan_Pepperdine_2_27_25.xlsx         guest
# 3959    RudyQuan_Pepperdine_2_27_25.xlsx         guest
# 3964    RudyQuan_Pepperdine_2_27_25.xlsx         guest
# 3969    RudyQuan_Pepperdine_2_27_25.xlsx         guest
#
# [147 rows x 27 columns]

# %% [markdown]
# Percent of return wins function

# %%
def return_wins_percent():

    #find the percent of games won when player is the host and the server is the guest 
    pct = (combined_data_games.loc[combined_data_games['Server'] == 'guest', ['Server','Game Winner']]
      ['Game Winner']
      .value_counts(normalize=True)
      .get('host', 0)* 100)
    
    return round(pct, 2)

print(return_wins_percent())
# Out:
# 50.0

# %% [markdown]
# ### Cj Work

# %%
import pandas as pd
import re 
import os

player_name = 'Rudy Quan'

combined_data_shots = pd.read_excel(f'../../data/mens/{player_name}/combined.xlsx', sheet_name='Shots')
combined_data_points = pd.read_excel(f'../../data/mens/{player_name}/combined.xlsx', sheet_name='Points')
combined_data_games = pd.read_excel(f'../../data/mens/{player_name}/combined.xlsx', sheet_name='Games')
combined_data_sets = pd.read_excel(f'../../data/mens/{player_name}/combined.xlsx', sheet_name='Sets')
combined_data_settings = pd.read_excel(f'../../data/mens/{player_name}/combined.xlsx', sheet_name='Settings')
